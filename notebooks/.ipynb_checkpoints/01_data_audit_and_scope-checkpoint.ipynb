# %% [markdown]
# # 01 — Audit des données et sélection du périmètre
#
# Ce notebook lit les artefacts produits par les scripts. La logique lourde reste dans `src/` afin de garantir la reproductibilité.

# %%
from pathlib import Path
import json
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
AUDIT = ROOT / "outputs" / "audit" / "raw_file_audit.csv"
SCOPE = ROOT / "artifacts" / "scope_manifest.json"

# %%
audit = pd.read_csv(AUDIT)
display(audit)
manifest = json.loads(SCOPE.read_text(encoding="utf-8"))
manifest
# Out:
#                   file   size_mb  row_count  column_count  duplicate_key_rows  \
# 0            train.csv  4765.942  125497040             6                   0
# 1             test.csv   120.318    3370464             5                   0
# 2            items.csv     0.097       4100             4                   0
# 3           stores.csv     0.001         54             5                   0
# 4              oil.csv     0.020       1218             2                   0
# 5  holidays_events.csv     0.021        350             6                   0
# 6     transactions.csv     1.481      83488             3                   0
#
#      date_min    date_max                                            columns
# 0  2013-01-01  2017-08-15  id|date|store_nbr|item_nbr|unit_sales|onpromotion
# 1  2017-08-16  2017-08-31             id|date|store_nbr|item_nbr|onpromotion
# 2         NaN         NaN                   item_nbr|family|class|perishable
# ...

# %% [markdown]
# ## Questions à documenter
#
# - Les clés sont-elles uniques ?
# - Quelle période est couverte ?
# - Quels magasins assurent une diversité de type et de cluster ?
# - Quelles familles couvrent volume, promotion, périssabilité et intermittence ?
